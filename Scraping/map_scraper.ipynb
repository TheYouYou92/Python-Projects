# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_legends():
    headers = {
        'authority': 'www.zeemaps.com',
        'accept': '*/*',
        'accept-language': 'en-US,en;q=0.9',
        # 'cookie': 'AWSALBCORS=2cpJWXoLZLRbcQWUpQbiPVY0bnrjfF2L3KiGiPWGfqVGi3aAr7ECpbR7ROsn/BYIyywW3IUX6y6o2xjjaOjZSFe+cvW7xVtaTwJDt2+hmyiB01JpXGXyPLjZ3iHs',
        'dnt': '1',
        'referer': 'https://www.zeemaps.com/pub?group=3839111&legend=1&search=1&simpleadd=1&track=UA-41067143-4&x=-100.193057&y=43.712520&z=13',
        'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
    }

    params = {
        'g': '3839111',
    }

    response = requests.get('https://www.zeemaps.com/legends/getall', params=params, headers=headers)
    return response.json()

# %%
legends = get_legends()

# %%
legends[:10]
# Out:
# [{'r': False, 'c': 1, 'v': 'Walls Mfr', 'id': 1, 'o': 3},
#  {'r': False, 'c': 2, 'v': 'No Walls - Mfr', 'id': 2, 'o': 1},
#  {'r': False, 'c': 3, 'v': 'Walls + Install', 'id': 3, 'o': 4},
#  {'r': False, 'c': 4, 'v': 'No Walls - Mfr + Install', 'id': 4, 'o': 2},
#  {'r': False, 'c': 5, 'v': 'Certified Framer', 'id': 5, 'o': 9},
#  {'r': False, 'c': 6, 'v': 'Kitchen + Bath Pods', 'id': 6, 'o': 8},
#  {'r': False, 'c': 7, 'v': 'Modular', 'id': 7, 'o': 7},
#  {'r': False, 'c': 8, 'v': 'Insulated Walls Mfr', 'id': 8, 'o': 5},
#  {'r': False, 'c': 9, 'v': 'Insulated Walls + Install', 'id': 9, 'o': 6},
#  {'r': False, 'c': 10, 'v': '', 'o': 10}]

# %%
def get_map_data():
    headers = {
        'authority': 'www.zeemaps.com',
        'accept': '*/*',
        'accept-language': 'en-US,en;q=0.9',
        # 'cookie': 'AWSALBCORS=uGND55OB9lfg6Q5Ed7wLPXVUcLVDFXPVK9AkvLGKzSokCZPlDmdYtxuhEZ8NfoC/APkPCOEuxM+ZxZQiOc5RtwFJyHJLmz91ydMVq+qYVWCrwyXXVwvg+BVwBZNb',
        'dnt': '1',
        'referer': 'https://www.zeemaps.com/pub?group=3839111&legend=1&search=1&simpleadd=1&track=UA-41067143-4&x=-100.193057&y=43.712520&z=13',
        'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
    }

    params = {
        'g': '3839111',
        'k': 'REGULAR',
        'e': 'true',
        '_dc': '0.871328547867334',
    }

    response = requests.get('https://www.zeemaps.com/emarkers', params=params, headers=headers)
    return response.json()

# %%
map_data = get_map_data()

# %%
map_data[0]
# Out:
# {'zip': '01007',
#  'a': '155 Bay Road, Belchertown 01007',
#  'b': 0,
#  'c': 'F',
#  'lng': -72.425715,
#  'city': 'Belchertown',
#  'ov': 'UFP - Belchertown LLC',
#  'clr': 1,
#  'cty': 'US',
#  's': '155 Bay Road',
#  'id': 268449601,
#  'state': 'MA',
#  'lat': 42.297956,
#  'nm': 'UFP - Belchertown LLC'}

# %%
len(map_data)
# Out:
# 1007

# %%
def ad_data(ad_id):
    headers = {
        'authority': 'www.zeemaps.com',
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'en-US,en;q=0.9',
        # 'cookie': 'AWSALBCORS=YwdG+boLVwzVJc8/aYrX5PdQyk0LsTbYHqqfb23bIcVNHd8tclJAD03w7BDWeqj4HZuq76ViJW+FtnJJuY+sHWH0mgDNNMtfHrJ2xvywlkc2WqC3+wxgQ31DjccM',
        'dnt': '1',
        'referer': 'https://www.zeemaps.com/pub?group=3839111&legend=1&search=1&simpleadd=1&track=UA-41067143-4&x=-100.193057&y=43.712520&z=13',
        'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
    }

    response = requests.get(
        f'https://www.zeemaps.com/etext?g=3839111&j=1&sh=&_dc=0.2903855366865178&eids=[{ad_id}]&emb=1&g=3839111',
        headers=headers,
    )
    return response.json()

# %%
ad_details_list = []

# %%
for i in map_data[:10]:
    try:
        ad_id = i['id']
        data = ad_data(ad_id)
        ad_details_list.append(data)
    except:
        continue

# %%
ad_details_list[0]['t']
# Out:
# "<center class='markersubtitle'><a target='_blank' href='https://www.ufpi.com/belchertown'>Website</a></center><span class='bold'>Description</span>&nbsp;UFP Belchertown is a leading Northeastern supplier of a wide variety of wood products, with a reputation for outstanding service, pricing and quality. Our products include roof and floor trusses, wall panels, EWP floor systems, Prowood treated lumber, and specialty insulation products<br/><span class='bold'>Phone</span>&nbsp;<span class='phone'>(413) 323-7247</span><br/><span class='bold'>Services</span>&nbsp;Mfr<br/><span class='bold'>Primary Structural Material</span>&nbsp;Wood<br/>"

# %%
response = requests.get('https://yts.mx/api/v2/list_movies.json?limit=500')
json = response.json()

# %%
json
# Out:
# {'status': 'ok',
#  'status_message': 'Query was successful',
#  'data': {'movie_count': 58700,
#   'limit': 20,
#   'page_number': 1,
#   'movies': [{'id': 59616,
#     'url': 'https://yts.mx/movies/no-looking-back-1998',
#     'imdb_code': 'tt0119560',
#     'title': 'No Looking Back',
#     'title_english': 'No Looking Back',
#     'title_long': 'No Looking Back (1998)',
#     'slug': 'no-looking-back-1998',
#     'year': 1998,
#     'rating': 5.9,
#     'runtime': 96,
#     'genres': ['Drama', 'Romance'],
# ...

# %%
movies[0]['synopsis']
# Out:
# "Misunderstood by his peers, rejected by the art establishment, wracked with grief over the loss of his older sister and tortured by addiction, the film captures Munch's life, painting an intimate and nuanced picture of a unique and multifaceted person and artist. This modern adaptation takes the viewers to four important chapters of his life: The story of Munch's first love, and the controversy around one of his early exhibitions in Berlin. This is followed by Munch's admission to a psychiatric clinic, where he was forced to make the biggest decision of his life. Finally, the film shows the artist's battle at the end of his life to save his works from the Nazis during World War II.—The Norwegian Film Institute"

# %%
len(movies)
# Out:
# 20
